# %% [markdown]
# ## Problem 1.1 Functions
#
# implement following simple functions

# %%
def square(x):
    #TBD
    pass

def times2(x):
    #TBD
    pass

def average(x1, x2, x3, x4, x5):
    #TBD
    pass
